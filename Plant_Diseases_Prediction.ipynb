# %% [markdown]
# <a href="https://colab.research.google.com/github/RutuJ1909/Plant-Diseases-Prediction/blob/main/Plant_Diseases_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict whether a plant is suffering from a disease. We will use different layers and other hyperparameters for building, training and testing this classifictaion model.We will be using tensorflow and keras for this project.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive/Data"
# Out:
# Plant_images_pianalytix

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook.
# Here you can see that I have 2 folders in my drive and 'Plant_images_pianlytix'  contains the images that we will work on.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Next we will import all the required libraries. As we are making a CNN model we will import all the required layers, activations, optimizers, etc.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/MyDrive/Data/Plant_images_pianalytix/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Now we will observe some of the iamges that are their in our dataset. We will plot 12 images here using the matplotlib library.

# %%
#Converting Images to array 
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))  
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.

# %%
dir = "/content/drive/MyDrive/Data/Plant_images_pianalytix"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# Now we will convert all the images into numpy array.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 2    300
# 1    300
# 0    300
# dtype: int64

# %% [markdown]
# We will also observe the number of images under different classes to see if the dataset is balanced or not

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# Next we will observe the shape of the image.

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %% [markdown]
# Checking the total number of the images which is the length of the labels list.

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Next we will use sklearn train_test_split to split the dataset into testing and training data. Here I have taken test size as 0.2 so my data will be divided into 80% training and 20% testing data.

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %% [markdown]
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 256, 256, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 85, 85, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 85, 85, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 42, 42, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 112896)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                7225408
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 7,244,995
# Trainable params: 7,244,995
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Next we will split the dataset into validation and training data.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 34s 6s/step - loss: 0.9128 - accuracy: 0.5330 - val_loss: 0.5880 - val_accuracy: 0.8611
# Epoch 2/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.4896 - accuracy: 0.8785 - val_loss: 0.3942 - val_accuracy: 0.9028
# Epoch 3/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.3198 - accuracy: 0.9115 - val_loss: 0.2848 - val_accuracy: 0.9236
# Epoch 4/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.2165 - accuracy: 0.9479 - val_loss: 0.2395 - val_accuracy: 0.9167
# Epoch 5/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.1605 - accuracy: 0.9601 - val_loss: 0.2023 - val_accuracy: 0.9306
# Epoch 6/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.1252 - accuracy: 0.9635 - val_loss: 0.1691 - val_accuracy: 0.9444
# Epoch 7/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0959 - accuracy: 0.9757 - val_loss: 0.1420 - val_accuracy: 0.9514
# Epoch 8/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0731 - accuracy: 0.9861 - val_loss: 0.1143 - val_accuracy: 0.9653
# Epoch 9/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0635 - accuracy: 0.9861 - val_loss: 0.1058 - val_accuracy: 0.9444
# Epoch 10/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0491 - accuracy: 0.9913 - val_loss: 0.0911 - val_accuracy: 0.9722
# Epoch 11/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0371 - accuracy: 0.9948 - val_loss: 0.0777 - val_accuracy: 0.9722
# Epoch 12/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0342 - accuracy: 0.9965 - val_loss: 0.0620 - val_accuracy: 0.9861
# Epoch 13/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0284 - accuracy: 0.9983 - val_loss: 0.0871 - val_accuracy: 0.9722
# Epoch 14/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.0499 - val_accuracy: 0.9861
# Epoch 15/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 0.9792
# Epoch 16/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9861
# Epoch 17/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0572 - val_accuracy: 0.9792
# Epoch 18/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0372 - val_accuracy: 0.9861
# Epoch 19/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9792
# Epoch 20/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9931
# Epoch 21/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9861
# Epoch 22/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9931
# Epoch 23/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 0.9792
# Epoch 24/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0326 - val_accuracy: 0.9931
# Epoch 25/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9861
# Epoch 26/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9931
# Epoch 27/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9931
# Epoch 28/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9931
# Epoch 29/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.9931
# Epoch 30/50
# 5/5 [==============================] - 33s 7s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9931
# Epoch 31/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9931
# Epoch 32/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9931
# Epoch 33/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9931
# Epoch 34/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9931
# Epoch 35/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 0.9931
# Epoch 36/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9861
# Epoch 37/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9931
# Epoch 38/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0308 - val_accuracy: 0.9931
# Epoch 39/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9931
# Epoch 40/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9931
# Epoch 41/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9931
# Epoch 42/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9931
# Epoch 43/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9931
# Epoch 44/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0362 - val_accuracy: 0.9931
# Epoch 45/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9931
# Epoch 46/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9931
# Epoch 47/50
# 5/5 [==============================] - 33s 6s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9931
# Epoch 48/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9931
# Epoch 49/50
# 5/5 [==============================] - 32s 6s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9931
# Epoch 50/50
# 5/5 [==============================] - 32s 6s/step - loss: 9.7206e-04 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9931

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 10 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already raeched a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
model.save("/content/drive/My Drive/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/My Drive/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/My Drive/plant_model_weights.h5')

# %% [markdown]
# Saving the model using different techniques.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the trainig history.

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 3s 482ms/step - loss: 0.0492 - accuracy: 0.9889
# Test Accuracy: 98.88888597488403

# %% [markdown]
# Evaluating the model to know the accuracy of the model.

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# Next we will use our model to predict predicting the testing dataset label.

# %%
# Plotting image to compare
img = array_to_img(x_test[11])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F62B7662350>

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight

# %% [markdown]
# Printing out the original and the predicted label.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the plant diseases using the image supplied to model.
# This model is highly beneficial as it can be used by different agricultural firms and farmers to increase their yield and stop wastage of crops due to disease.
